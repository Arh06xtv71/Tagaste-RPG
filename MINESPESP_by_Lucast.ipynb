# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.18.2' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx14G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2dsnw7uiJXUWVic930KSr6l7Z0s_41bBFJfKAbxXnJJKnb2DZ" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# Minecraft-server     eula.txt	    mohist.jar	       spigot.yml
# banned-ips.json      forge.jar	    ops.json	       trees
# banned-players.json  forge.jar.log  patchouli_books    user_jvm_args.txt
# bukkit.yml	     help.yml	    permissions.yml    usercache.json
# colabconfig.json     libraries	    plugins	       usernamecache.json
# commands.yml	     logs	    run.bat	       whitelist.json
# config		     mods	    run.sh	       world
# defaultconfigs	     mohist-config  server.properties
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 8.tcp.ngrok.io:17198
# Estas jugando a minecraft: mohist en su version: 1.18.2
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.18.2-146, Java(21.0.2) 65.0
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 156, but you have 146. The latest version has been built on 2024-03-15 09:28:10. You should update to fix recent bugs!
# Checking libraries, please wait...
# DownloadSource: MOHIST
# Download percentage:
#    0% [                                                    ] 0/1 (0:00:00 / ?)
# All libraries are nice :)!===========================] 1/1 (0:00:00 / 0:00:00)
# [02:07:57 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 40.2.17, --fml.mcVersion, 1.18.2, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20220404.173914, nogui]
# [02:07:57 INFO]: ModLauncher 9.1.3+9.1.3+main.9b69c82a starting: java version 21.0.2 by Microsoft
# [02:07:57 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2316!/ Service=ModLauncher Env=SERVER
# [02:07:57 INFO]: No dependencies to load found. Skipping!
# [02:08:00 INFO]: Compatibility level set to JAVA_17
# [02:08:01 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [02:08:01 WARN]: Reference map 'creativecore.mixins.refmap.json' for creativecore.mixins.json could not be read. If this is a development environment you can ignore this message
# [02:08:01 WARN]: Reference map 'cristellib-common-refmap.json' for cristellib-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [02:08:01 WARN]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [02:08:01 INFO]: No config file detected. Creating one...
# [02:08:01 INFO]: Overriding config for 'terrablender_compatibility': FALSE (Terrablender not installed)
# [02:08:01 INFO]: No config file detected. Creating one...
# [02:08:01 INFO]: Overriding config for 'cursed_skylands': NONE (Terrablender not installed)
# [02:08:05 WARN]: @Final field f_31427_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [02:08:05 WARN]: @Final field f_31428_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [02:08:11 INFO]: [Collective] JSON file 'entity_names.json' generation requested by mod 'villagernames'.
# [02:08:11 INFO]: register skill wom:ender_step
# [02:08:11 INFO]: register skill wom:ender_obscuris
# [02:08:11 INFO]: register skill wom:dodge_master
# [02:08:11 INFO]: register skill wom:precise_roll
# [02:08:11 INFO]: register skill wom:shadow_step
# [02:08:11 INFO]: register skill wom:bull_charge
# [02:08:11 INFO]: register skill wom:demon_mark_passive
# [02:08:11 INFO]: register skill wom:torment_passive
# [02:08:11 INFO]: register skill wom:ruine_passive
# [02:08:11 INFO]: register skill wom:lunar_echo_passive
# [02:08:11 INFO]: register skill wom:satsujin_passive
# [02:08:11 INFO]: register skill wom:charybdis
# [02:08:11 INFO]: register skill wom:agony_plunge
# [02:08:11 INFO]: register skill wom:true_berserk
# [02:08:11 INFO]: register skill wom:plunder_perdition
# [02:08:11 INFO]: register skill wom:sakura_state
# [02:08:11 INFO]: register skill wom:ender_blast
# [02:08:11 INFO]: register skill wom:ender_fusion
# [02:08:11 INFO]: register skill wom:demonic_ascension
# [02:08:11 INFO]: register skill epicfight:basic_attack
# [02:08:11 INFO]: register skill epicfight:air_attack
# [02:08:11 INFO]: register skill epicfight:roll
# [02:08:11 INFO]: register skill epicfight:step
# [02:08:11 INFO]: register skill epicfight:knockdown_wakeup
# [02:08:11 INFO]: register skill wom:regierung
# [02:08:11 INFO]: register skill wom:lunar_eclipse
# [02:08:11 INFO]: register skill epicfight:guard
# [02:08:11 INFO]: register skill wom:counter_attack
# [02:08:11 INFO]: register skill epicfight:parrying
# [02:08:11 INFO]: register skill wom:perfect_bulwark
# [02:08:11 INFO]: register skill wom:vengeful_parry
# [02:08:11 INFO]: register skill wom:arrow_tenacity
# [02:08:11 INFO]: register skill epicfight:impact_guard
# [02:08:11 INFO]: register skill epicfight:berserker
# [02:08:11 INFO]: register skill epicfight:death_harvest
# [02:08:11 INFO]: register skill wom:pain_anticipation
# [02:08:11 INFO]: register skill epicfight:emergency_escape
# [02:08:11 INFO]: register skill wom:latent_retribution
# [02:08:11 INFO]: register skill wom:vampirize
# [02:08:11 INFO]: register skill epicfight:endurance
# [02:08:11 INFO]: register skill wom:critical_knowledge
# [02:08:11 INFO]: register skill epicfight:forbidden_strength
# [02:08:11 INFO]: register skill epicfight:hypervitality
# [02:08:11 INFO]: register skill epicfight:stamina_pillager
# [02:08:11 INFO]: register skill wom:heart_shield
# [02:08:11 INFO]: register skill epicfight:swordmaster
# [02:08:11 INFO]: register skill epicfight:technician
# [02:08:11 INFO]: register skill epicfight:sweeping_edge
# [02:08:11 INFO]: register skill epicfight:dancing_edge
# [02:08:11 INFO]: register skill wom:mindset
# [02:08:11 INFO]: register skill wom:adrenaline
# [02:08:11 INFO]: register skill epicfight:the_guillotine
# [02:08:11 INFO]: register skill epicfight:grasping_spire
# [02:08:11 INFO]: register skill wom:dancing_blade
# [02:08:11 INFO]: register skill epicfight:heartpiercer
# [02:08:11 INFO]: register skill epicfight:steel_whirlwind
# [02:08:11 INFO]: register skill wom:meditation
# [02:08:11 INFO]: register skill epicfight:battojutsu
# [02:08:11 INFO]: register skill epicfight:battojutsu_passive
# [02:08:11 INFO]: register skill epicfight:rushing_tempo
# [02:08:11 INFO]: register skill epicfight:relentless_combo
# [02:08:11 INFO]: register skill epicfight:liechtenauer
# [02:08:11 INFO]: register skill epicfight:sharp_stab
# [02:08:11 INFO]: register skill epicfight:eviscerate
# [02:08:12 INFO]: Loading Collective version 7.7.
# [02:08:12 INFO]: register skill epicfight:blade_rush
# [02:08:12 INFO]: register skill epicfight:wrathful_lighting
# [02:08:12 INFO]: register skill epicfight:tsunami
# [02:08:12 INFO]: register skill epicfight:everlasting_allegiance
# [02:08:12 INFO]: register skill epicfight:meteor_slam
# [02:08:12 INFO]: register skill epicfight:revelation
# [02:08:12 INFO]: register skill epicfight:demolition_leap
# [02:08:12 INFO]: register skill epicfight:phantom_ascent
# [02:08:12 INFO]: Terrablender not detected
# [02:08:12 INFO]: Datapack registered with CristelLib
# [02:08:12 INFO]: Forge mod loading, version 40.2.17, for MC 1.18.2 with MCP 20220404.173914
# [02:08:12 INFO]: MinecraftForge v40.2.17 Initialized
# [02:08:12 INFO]: EventDispatcherRegistry initialized
# [02:08:13 INFO]: dumping Runtime Pack's assets and data
# [02:08:14 ERROR]: Error whilst loading type "Family" with name "dtterralith:moonlight": [common_leaves] Could not find LeavesProperties for registry name 'dtterralith:moonlight_spruce'.
# [02:08:16 INFO]: Potentially Dangerous alternative prefix `betteroceanmonuments` for name `ocean_monument`, expected `yungsapi`. This could be a intended override, but in most cases indicates a broken mod.
# [02:08:16 INFO]: Potentially Dangerous alternative prefix `betterfortresses` for name `fortress`, expected `yungsapi`. This could be a intended override, but in most cases indicates a broken mod.
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Sheath_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Sheath_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/agony_walk
# [02:08:17 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/agony_walk
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Sheath_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_idle
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_idle
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_idle
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_walk
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_walk
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_run
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_run
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/herrscher_guard
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/herrscher_guard
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_hit
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_hit
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_parry
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_parry
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [02:08:18 WARN]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [02:08:19 WARN]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [02:08:19 WARN]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [02:08:19 WARN]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [02:08:22 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [02:08:23 WARN]: Assets URL 'union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar%23100!/assets/.mcassetsroot' uses unexpected schema
# [02:08:23 WARN]: Assets URL 'union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar%23100!/data/.mcassetsroot' uses unexpected schema
# [02:08:30 WARN]: Ambiguity between arguments [teleport, location] and [teleport, destination] with inputs: [0.1 -0.5 .9, 0 0 0]
# [02:08:30 WARN]: Ambiguity between arguments [teleport, location] and [teleport, targets] with inputs: [0.1 -0.5 .9, 0 0 0]
# [02:08:30 WARN]: Ambiguity between arguments [teleport, destination] and [teleport, targets] with inputs: [Player, 0123, @e, dd12be42-52a9-4a91-a8a1-11c01849e498]
# [02:08:30 WARN]: Ambiguity between arguments [teleport, targets] and [teleport, destination] with inputs: [Player, 0123, dd12be42-52a9-4a91-a8a1-11c01849e498]
# [02:08:30 WARN]: Ambiguity between arguments [teleport, targets, location] and [teleport, targets, destination] with inputs: [0.1 -0.5 .9, 0 0 0]
# [02:08:30 WARN]: Ambiguity between arguments [mahousummon, treasury, stack, pos, anim_speed, proj_speed, acc, r, g, b, aim] and [mahousummon, treasury, stack, pos, anim_speed, proj_speed, acc, r, g, b, target] with inputs: [0.1 -0.5 .9, 0 0 0]
# [02:08:30 WARN]: Ambiguity between arguments [mahousummon, wepproj, stack, pos, proj_speed, acc, aim] and [mahousummon, wepproj, stack, pos, proj_speed, acc, target] with inputs: [0.1 -0.5 .9, 0 0 0]
# [02:08:30 WARN]: Ambiguity between arguments [deathhistory, player] and [deathhistory, player_uuid] with inputs: [dd12be42-52a9-4a91-a8a1-11c01849e498]
# [02:08:39 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_5_via_sewing as it's serializer returned null
# [02:08:39 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_1_via_sewing as it's serializer returned null
# [02:08:39 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_7_via_sewing as it's serializer returned null
# [02:08:39 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_2_via_sewing as it's serializer returned null
# [02:08:39 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_4_via_sewing as it's serializer returned null
# [02:08:39 INFO]: Skipping loading recipe toolbelt:belt_via_sewing as it's serializer returned null
# [02:08:39 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_6_via_sewing as it's serializer returned null
# [02:08:39 INFO]: Skipping loading recipe toolbelt:pouch_via_sewing as it's serializer returned null
# [02:08:39 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_3_via_sewing as it's serializer returned null
# [02:08:40 INFO]: Loaded 7 recipes
# [02:08:40 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_5_via_sewing as it's serializer returned null
# [02:08:40 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_1_via_sewing as it's serializer returned null
# [02:08:40 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_7_via_sewing as it's serializer returned null
# [02:08:40 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_2_via_sewing as it's serializer returned null
# [02:08:40 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_4_via_sewing as it's serializer returned null
# [02:08:40 INFO]: Skipping loading recipe toolbelt:belt_via_sewing as it's serializer returned null
# [02:08:40 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_6_via_sewing as it's serializer returned null
# [02:08:40 INFO]: Skipping loading recipe toolbelt:pouch_via_sewing as it's serializer returned null
# [02:08:40 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_3_via_sewing as it's serializer returned null
# [02:08:41 INFO]: Beginning loading of data for data loader: ancient/mob_ancient_data
# [02:08:41 INFO]: Data loader for ancient/mob_ancient_data loaded 1 finalized objects
# [02:08:41 INFO]: Beginning loading of data for data loader: summon
# [02:08:41 INFO]: Data loader for summon loaded 8 jsons
# [02:08:41 INFO]: Beginning loading of data for data loader: material/weapon
# [02:08:41 INFO]: Data loader for material/weapon loaded 0 jsons
# [02:08:41 INFO]: Beginning loading of data for data loader: material/armor
# [02:08:41 INFO]: Data loader for material/armor loaded 2 jsons
# [02:08:41 INFO]: Beginning loading of data for data loader: gearconfig/melee
# [02:08:41 INFO]: Data loader for gearconfig/melee loaded 0 jsons
# [02:08:41 INFO]: Beginning loading of data for data loader: gearconfig/armor
# [02:08:41 INFO]: Data loader for gearconfig/armor loaded 15 jsons
# [02:08:41 INFO]: Beginning loading of data for data loader: gearconfig/bow
# [02:08:41 INFO]: Data loader for gearconfig/bow loaded 0 jsons
# [02:08:41 INFO]: Beginning loading of data for data loader: gearconfig/crossbow
# [02:08:41 INFO]: Data loader for gearconfig/crossbow loaded 0 jsons
# [02:08:41 INFO]: Beginning loading of data for data loader: elite_mob
# [02:08:41 INFO]: Data loader for elite_mob loaded 6 finalized objects
# [02:08:42 ERROR]: Error whilst loading type "Family" with name "dtterralith:moonlight": [common_leaves] Could not find LeavesProperties for registry name 'dtterralith:moonlight_spruce'.
# [02:08:42 WARN]: Could not get any biomes from selector:
# {"name":"terralith:lush_desert"}
# [02:08:43 INFO]: Starting minecraft server version 1.18.2
# [02:08:43 INFO]: Loading properties
# [02:08:43 INFO]: Default game type: SURVIVAL
# [02:08:43 INFO]: Generating keypair
# [02:08:44 INFO]: Starting Minecraft server on *:25565
# [02:08:44 INFO]: Using epoll channel type
# [02:08:44 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [02:08:44 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [02:08:44 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [02:08:44 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [02:08:44 INFO]: This server is running Mohist version 1.18.2-146 (MC: 1.18.2) (Implementing API version 1.18.2-R0.1-SNAPSHOT, Forge version 40.2.17)
# [02:08:46 INFO]: Debug logging is enabled
# [02:08:46 INFO]: Server Ping Player Sample Count: 12
# [02:08:46 INFO]: Using 4 threads for Netty based IO
# [02:08:48 INFO]: [SkinsRestorer] Loading SkinsRestorer v15.0.7
# [02:08:48 INFO]: [SinglePlayerSleep] Loading SinglePlayerSleep v1.13_2.13.50
# [02:08:48 INFO]: [NametagEdit] Loading NametagEdit v4.5.23
# [02:08:48 INFO]: [LoginSecurity] Loading LoginSecurity v3.2.0
# [02:08:48 INFO]: [SkinsRestorer] Enabling SkinsRestorer v15.0.7
# [02:08:53 INFO]: [SkinsRestorer] Running on Minecraft 1.18.2.
# [02:08:54 INFO]: Preparing level "world"
# [02:08:54 INFO]: Preparing start region for dimension minecraft:overworld
# [02:08:56 INFO]: Preparing spawn area: 0%
# [02:08:56 INFO]: Preparing spawn area: 0%
# [02:08:56 INFO]: Preparing spawn area: 0%
# [02:08:56 INFO]: Preparing spawn area: 0%
# [02:08:56 INFO]: Preparing spawn area: 0%
# [02:08:57 INFO]: Preparing spawn area: 0%
# [02:08:57 INFO]: Preparing spawn area: 0%
# [02:08:58 INFO]: Preparing spawn area: 0%
# [02:08:58 INFO]: Preparing spawn area: 0%
# [02:08:59 INFO]: Preparing spawn area: 0%
# [02:09:00 INFO]: Preparing spawn area: 0%
# [02:09:00 INFO]: Preparing spawn area: 0%
# [02:09:00 INFO]: Preparing spawn area: 1%
# [02:09:01 INFO]: Preparing spawn area: 4%
# [02:09:01 INFO]: Preparing spawn area: 4%
# [02:09:02 INFO]: Preparing spawn area: 10%
# [02:09:02 INFO]: Preparing spawn area: 12%
# [02:09:03 INFO]: Preparing spawn area: 24%
# [02:09:03 INFO]: Preparing spawn area: 24%
# [02:09:04 INFO]: Preparing spawn area: 38%
# [02:09:04 INFO]: Preparing spawn area: 54%
# [02:09:05 INFO]: Preparing spawn area: 74%
# [02:09:06 INFO]: Time elapsed: 11843 ms
# [02:09:06 INFO]: Preparing start region for dimension mahoutsukai:reality_marble
# [02:09:07 INFO]: Preparing spawn area: 0%
# [02:09:07 INFO]: Preparing spawn area: 0%
# [02:09:07 INFO]: Preparing spawn area: 0%
# [02:09:08 INFO]: Preparing spawn area: 0%
# [02:09:08 INFO]: Preparing spawn area: 0%
# [02:09:09 INFO]: Preparing spawn area: 1%
# [02:09:09 INFO]: Preparing spawn area: 1%
# [02:09:10 INFO]: Preparing spawn area: 15%
# [02:09:10 INFO]: Preparing spawn area: 72%
# [02:09:11 INFO]: Preparing spawn area: 86%
# [02:09:12 INFO]: Preparing spawn area: 88%
# [02:09:12 INFO]: Preparing spawn area: 88%
# [02:09:12 INFO]: Time elapsed: 5766 ms
# [02:09:12 INFO]: Preparing start region for dimension minecraft:the_end
# [02:09:13 INFO]: Preparing spawn area: 0%
# [02:09:13 INFO]: Preparing spawn area: 0%
# [02:09:13 INFO]: Preparing spawn area: 0%
# [02:09:14 INFO]: Preparing spawn area: 4%
# [02:09:14 INFO]: Preparing spawn area: 30%
# [02:09:15 INFO]: Preparing spawn area: 63%
# [02:09:15 INFO]: Time elapsed: 2756 ms
# [02:09:15 INFO]: Preparing start region for dimension minecraft:the_nether
# [02:09:16 INFO]: Preparing spawn area: 0%
# [02:09:16 INFO]: Preparing spawn area: 0%
# [02:09:16 INFO]: Preparing spawn area: 0%
# [02:09:17 INFO]: Preparing spawn area: 0%
# [02:09:17 INFO]: Preparing spawn area: 0%
# [02:09:17 INFO]: Preparing spawn area: 0%
# [02:09:18 INFO]: Preparing spawn area: 4%
# [02:09:18 INFO]: Preparing spawn area: 11%
# [02:09:19 INFO]: Preparing spawn area: 22%
# [02:09:20 INFO]: Preparing spawn area: 54%
# [02:09:20 INFO]: Time elapsed: 5011 ms
# [02:09:20 INFO]: [SinglePlayerSleep] Enabling SinglePlayerSleep v1.13_2.13.50
# [02:09:20 INFO]: **************************************
# [02:09:20 INFO]: SinglePlayerSleep v1.13_2.13.50 Loading...
# [02:09:20 INFO]: SinglePlayerSleep v1.13_2.13.50 plugins/SinglePlayerSleep/config.yml
# [02:09:20 INFO]: Checking for updates...
# [02:09:20 INFO]: SinglePlayerSleep v1.13_2.13.50 *!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*
# [02:09:20 INFO]: SinglePlayerSleep v1.13_2.13.50 * Version is up to date!
# [02:09:20 INFO]: SinglePlayerSleep v1.13_2.13.50 * Donate: https://ko-fi.com/joelgodofwar
# [02:09:20 INFO]: SinglePlayerSleep v1.13_2.13.50 *!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*!*
# [02:09:20 INFO]: SinglePlayerSleep v1.13_2.13.50 plugins/SinglePlayerSleep/permissions.yml
# [02:09:20 INFO]: SinglePlayerSleep v1.13_2.13.50 This server is running Mohist version 1.18.2-146 (MC: 1.18.2) (Implementing API version 1.18.2-R0.1-SNAPSHOT)
# [02:09:20 INFO]: SinglePlayerSleep v1.13_2.13.50 vardebug=false debug=false in plugins/SinglePlayerSleep/config.yml
# [02:09:20 INFO]: SinglePlayerSleep v1.13_2.13.50 jarfilename=/workspaces/codespaces-jupyter/Minecraft-server/plugins/SinglePlayerSleep-1.13_2.13.50.jar
# [02:09:20 INFO]: **************************************
# [02:09:20 INFO]: SinglePlayerSleep v1.13_2.13.50 is ENABLED - Loading took 341 ms.
# [02:09:20 INFO]: **************************************
# [02:09:20 INFO]: [NametagEdit] Enabling NametagEdit v4.5.23
# [02:09:21 INFO]: [NametagEdit] Successfully loaded using bukkit version: v1_18_R1
# [02:09:21 INFO]: [LoginSecurity] Enabling LoginSecurity v3.2.0
# [02:09:21 INFO]: [LoginSecurity] Loading base translations from "en_us"
# [02:09:21 INFO]: [LoginSecurity] Loading specified translations from "en_us"
# [02:09:21 INFO]: [LoginSecurity] Registering commands...
# [02:09:22 INFO]: [LoginSecurity] Registering listeners...
# [02:09:22 INFO]: [LoginSecurity] Using 1.12+ map captcha renderer
# [02:09:22 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [02:09:22 INFO]: Done (28.081s)! For help, type "help"
# [02:09:22 INFO]: Successfully initialized permission handler forge:default_handler
# [02:09:22 INFO]: Sending reload packet to clients
# [02:09:22 INFO]: [SkinsRestorer] ----------------------------------------------
# [02:09:22 INFO]: [SkinsRestorer]     +==================+
# [02:09:22 INFO]: [SkinsRestorer]     |   SkinsRestorer  |
# [02:09:22 INFO]: [SkinsRestorer]     |------------------|
# [02:09:22 INFO]: [SkinsRestorer]     |  Standalone Mode |
# [02:09:22 INFO]: [SkinsRestorer]     +==================+
# [02:09:22 INFO]: [SkinsRestorer] ----------------------------------------------
# [02:09:22 INFO]: [SkinsRestorer]     Version: 15.0.7
# [02:09:22 INFO]: [SkinsRestorer]     Commit: 301d078
# [02:09:22 INFO]: [SkinsRestorer]     This is the latest version!
# [02:09:22 INFO]: [SkinsRestorer] ----------------------------------------------
# [02:09:44 INFO]: UUID of player DeadlyBeast479 is baa9889a-d03e-36e2-90bb-5403da00fd06
# [02:09:45 INFO]: Using new advancement loading for net.minecraft.server.PlayerAdvancements@100e0612
# [02:09:46 INFO]: DeadlyBeast479[localhost/127.0.0.1:50748] logged in with entity id 993 at (-565.0173381632156, 62.0, -296.69999998807907)
# [02:09:53 INFO]: UUID of player garpy89 is d1723830-4a1e-3aec-937f-2a8f56211986
# [02:09:54 INFO]: Using new advancement loading for net.minecraft.server.PlayerAdvancements@3cd1d239
# [02:09:55 INFO]: garpy89[localhost/127.0.0.1:37158] logged in with entity id 1011 at (-553.6262734782704, 63.41999998688698, 806.407041855607)
# [02:10:05 INFO]: UUID of player DtmSazp is 382f315c-2e21-31be-b27d-4da5d3fed2dc
# [02:10:05 WARN]: Can't keep up! Is the server overloaded? Running 10340ms or 206 ticks behind
# [02:10:06 INFO]: Using new advancement loading for net.minecraft.server.PlayerAdvancements@41c9848a
# [02:10:06 INFO]: DtmSazp[localhost/127.0.0.1:37170] logged in with entity id 1125 at (-1075.065278493805, 78.76636799395752, -302.30052379989075)
# [02:10:24 INFO]: Stopping server
# [02:10:24 INFO]: Saving players
# [02:10:24 INFO]: DeadlyBeast479 lost connection: Server closed
# [02:10:24 INFO]: DeadlyBeast479 left the game.
# [02:10:24 INFO]: garpy89 lost connection: Server closed
# [02:10:24 INFO]: garpy89 left the game.
# [02:10:24 INFO]: DtmSazp lost connection: Server closed
# [02:10:24 INFO]: DtmSazp left the game.
# [02:10:24 INFO]: Saving worlds
# [02:10:31 INFO]: Saving chunks for level 'ServerLevel[world]'/minecraft:overworld
# > ^C
#
# >[02:10:50 ERROR]: Caught previously unhandled exception :
# java.lang.NoClassDefFoundError: org/jline/terminal/Terminal$MouseTracking
# 	at org.jline.reader.impl.LineReaderImpl.doCleanup(LineReaderImpl.java:2540) ~[jline-reader-3.21.0.jar%2313!/:?]
# 	at org.jline.reader.impl.LineReaderImpl.cleanup(LineReaderImpl.java:2526) ~[jline-reader-3.21.0.jar%2313!/:?]
# 	at org.jline.reader.impl.LineReaderImpl.readLine(LineReaderImpl.java:727) ~[jline-reader-3.21.0.jar%2313!/:?]
# 	at org.jline.reader.impl.LineReaderImpl.readLine(LineReaderImpl.java:468) ~[jline-reader-3.21.0.jar%2313!/:?]
# 	at net.minecraftforge.server.console.TerminalHandler.handleCommands(TerminalHandler.java:46) ~[forge-1.18.2-40.2.17-universal.jar%23105!/:?]
# 	at net.minecraft.server.dedicated.DedicatedServer$1.run(DedicatedServer.java:102) ~[server-1.18.2-20220404.173914-srg.jar%23100!/:?]
# Caused by: java.lang.ClassNotFoundException: org.jline.terminal.Terminal$MouseTracking
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:141) ~[securejarhandler-1.0.8.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	... 6 more
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
